# %% [markdown]
# 3B
#
# Set initial sx0 = -3050 km
# Set initial sy0 = -3 Rp
# Initialize integration time tf for sy0 = -3 Rp
# FOR i from 0 to 9:
#     Compute trajectory with current sy0 and tf
#     Find closest approach altitude ac
#     Print sy0 (in Rp units) and ac (km), rounded to 1 decimal
#     Double sy0
#     Double tf
#
# Set sy0 = -96 Rp
# Set tf = 1280 minutes
# Set target altitude atarget = 195 km
# Initialize dt = 60 seconds
# WHILE percentage error > 2%:
#     Start timer (time.perf_counter)
#     Compute trajectory with current dt
#     Find closest approach altitude ac
#     Compute percentage error = 100*(ac - atarget)/atarget
#     Stop timer, record elapsed time
#     Print dt, ac, percentage error, elapsed time
#     Halve dt
# END WHILE
# Make subplot figure:
#     Top plot: percentage error vs 1/dt
#     Bottom plot: percentage error vs dt
#     Annotate final dt and
#
#
# # Comment in code:
# # Suggest adaptive time stepping: use larger dt when far from planet,
# # smaller dt near closest approach to retain accuracy but reduce computation time.
# computation time
#
# END FOR

# %% [markdown]
# 3C
#
# Set sy0 = -96 Rp
# Set tf = 1280 minutes
# Set atarget = 195 km
# Set dt = 5 seconds
#
# FOR vy0 from 4.0 to 8.0 km/s in steps of 0.5:
#     FOR sx0 from -(Rp + 4*atarget) to -(Rp + atarget) in steps of atarget:
#         Compute trajectory with (sx0, vy0)
#         Find closest approach altitude ac
#         Store ac in results matrix
#     END FOR
# END FOR
#
# Make contour plot:
#     x-axis = sx0, y-axis = vy0
#     Contour ac values
#     Highlight region where ac is within ±5 km of atarget
#     Do not contour crash cases

# %% [markdown]
# 3D
#
# Use results from Part 3C (including failed experiments)
# FOR each (sx0, vy0) that produced a crash:
#     Compute crash site coordinates
#     Compute arc distance from south pole (x = -Rp, y = 0)
#     IF arc distance < 500 km AND sx0 < -1 Rp:
#         Save (sx0, vy0) as candidate
#     END IF
# END FOR
#
# Select one or two candidate starting conditions
# Plot trajectory up to crash site
# Label crash site on plot
# Print initial conditions (vy0, sx0) that caused crash
